# %%
import io
import chess
import chess.pgn
import chess.svg
import requests

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        sliceIndex = gameUnparsed.find('1. ')
        sliced = gameUnparsed[sliceIndex:]
        pgn = io.StringIO(sliced)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        # chess.svg.board(board)  
        chess.svg.piece(chess.Piece.from_symbol("R")) 
        break
    break

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        sliceIndex = gameUnparsed.find('1. ')
        sliced = gameUnparsed[sliceIndex:]
        pgn = io.StringIO(sliced)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        # chess.svg.board(board)  
        chess.svg.piece(chess.Piece.from_symbol("R")) 
        break
    break

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        sliceIndex = gameUnparsed.find('1. ')
        sliced = gameUnparsed[sliceIndex:]
        pgn = io.StringIO(sliced)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        # chess.svg.board(board)  
        chess.svg.piece(chess.Piece.from_symbol("R")) 
        break
    break

# %%
import chess
import chess.svg

chess.svg.piece(chess.Piece.from_symbol("R"))
# Out:
# '<svg version="1.1" viewBox="0 0 45 45" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="white rook" fill="#fff" fill-rule="evenodd" id="white-rook" stroke="#000" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"><path d="M9 39h27v-3H9v3zM12 36v-4h21v4H12zM11 14V9h4v2h5V9h5v2h5V9h4v5" stroke-linecap="butt" /><path d="M34 14l-3 3H14l-3-3" /><path d="M31 17v12.5H14V17" stroke-linecap="butt" stroke-linejoin="miter" /><path d="M31 29.5l1.5 2.5h-20l1.5-2.5" /><path d="M11 14h23" fill="none" stroke-linejoin="miter" /></g></svg>'

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests
from IPython.display import display

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        sliceIndex = gameUnparsed.find('1. ')
        sliced = gameUnparsed[sliceIndex:]
        pgn = io.StringIO(sliced)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        # chess.svg.board(board)  
        disaply(chess.svg.piece(chess.Piece.from_symbol("R")))
        break
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f04428f00c43> in <module>
#      30         board = parsed.board()
#      31         # chess.svg.board(board)
# ---> 32         disaply(chess.svg.piece(chess.Piece.from_symbol("R")))
#      33         break
#      34     break
#
# NameError: name 'disaply' is not defined

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests
from IPython.display import display

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        sliceIndex = gameUnparsed.find('1. ')
        sliced = gameUnparsed[sliceIndex:]
        pgn = io.StringIO(sliced)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        # chess.svg.board(board)  
        display(chess.svg.piece(chess.Piece.from_symbol("R")))
        break
    break
# Out:
# '<svg version="1.1" viewBox="0 0 45 45" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="white rook" fill="#fff" fill-rule="evenodd" id="white-rook" stroke="#000" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"><path d="M9 39h27v-3H9v3zM12 36v-4h21v4H12zM11 14V9h4v2h5V9h5v2h5V9h4v5" stroke-linecap="butt" /><path d="M34 14l-3 3H14l-3-3" /><path d="M31 17v12.5H14V17" stroke-linecap="butt" stroke-linejoin="miter" /><path d="M31 29.5l1.5 2.5h-20l1.5-2.5" /><path d="M11 14h23" fill="none" stroke-linejoin="miter" /></g></svg>'

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests
from IPython.display import display

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        sliceIndex = gameUnparsed.find('1. ')
        sliced = gameUnparsed[sliceIndex:]
        pgn = io.StringIO(sliced)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        display(parsed.headers["Event"])
        break
    break

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests
from IPython.display import display

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']

        pgn = io.StringIO(gameUnparsed)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        print('board is ', board)

        break
    break

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests
from IPython.display import display

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        sliceIndex = gameUnparsed.find('1. ')
        sliced = gameUnparsed[sliceIndex:]
        pgn = io.StringIO(sliced)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        display(parsed.headers["Event"])
        break
    break
# Out:
# '?'

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests
from IPython.display import display

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        pgn = io.StringIO(sliced)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        print(parsed)
        break
    break
# Out:
# [Event "?"]
# [Site "?"]
# [Date "????.??.??"]
# [Round "?"]
# [White "?"]
# [Black "?"]
# [Result "1-0"]
#
# 1. d4 { [%clk 0:02:00] } 1... d5 { [%clk 0:02:01] } 2. c4 { [%clk 0:01:59.6] } 2... e5 { [%clk 0:02:00.8] } 3. dxe5 { [%clk 0:01:59.3] } 3... d4 { [%clk 0:02:00.6] } 4. g3 { [%clk 0:01:59.8] } 4... c5 { [%clk 0:01:57.3] } 5. Bg2 { [%clk 0:02:00.1] } 5... Qe7 { [%clk 0:01:48.5] } 6. Nf3 { [%clk 0:01:59.4] } 6... Bg4 { [%clk 0:01:46.7] } 7. O-O { [%clk 0:01:59.2] } 7... Bxf3 { [%clk 0:01:46.3] } 8. Bxf3 { [%clk 0:01:59] } 8... Nc6 { [%clk 0:01:46.4] } 9. Bxc6+ { [%clk 0:01:56] } 9... bxc6 { [%clk 0:01:46.4] } 10. f4 { [%clk 0:01:56.4] } 10... g6 { [%clk 0:01:39] } 11. e3 { [%clk 0:01:56] } 11... Bg7 { [%clk 0:01:38.8] } 12. exd4 { [%clk 0:01:55.5] } 12... cxd4 { [%clk 0:01:38.8] } 13. Qxd4 { [%clk 0:01:55.7] } 13... Nh6 { [%clk 0:01:27.4] } 14. Qd6 { [%clk 0:01:55.2] } 14... Qxd6 { [%clk 0:01:12.8] } 15. exd6 { [%clk 0:01:55] } 15... O-O { [%clk 0:01:11.7] } 16. Nc3 { [%clk 0:01:54.2] } 16... Rfd8 { [%clk 0:01:10.8] } 17. Ne4 { [%clk 0:01:53] } 17... f5 { [%clk 0:01:10.1] } 18. Ng5 { [%clk 0:01:52.8] } 18... Rxd6 { [%clk 0:01:07.1] } 19. Be3 { [%clk 0:01:52.8] } 19... Bf6 { [%clk 0:01:03.3] } 20. Rad1 { [%clk 0:01:51.3] } 20... Rxd1 { [%clk 0:01:02.5] } 21. Rxd1 { [%clk 0:01:50.9] } 21... Bxg5 { [%clk 0:01:02.6] } 22. fxg5 { [%clk 0:01:50.9] } 22... Nf7 { [%clk 0:01:02.6] } 23. Bf4 { [%clk 0:01:51] } 23... h6 { [%clk 0:00:54] } 24. gxh6 { [%clk 0:01:48.8] } 24... Kh7 { [%clk 0:00:54.2] } 25. h4 { [%clk 0:01:47.8] } 25... Nxh6 { [%clk 0:00:53.9] } 26. Rd7+ { [%clk 0:01:47] } 26... Kg8 { [%clk 0:00:49] } 27. Bxh6 { [%clk 0:01:46.9] } 27... a6 { [%clk 0:00:48.8] } 1-0

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests
from IPython.display import display

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        pgn = io.StringIO(gameUnparsed)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        print(parsed)
        # display(chess.svg.board(board))
        break
    break
# Out:
# [Event "Live Chess"]
# [Site "Chess.com"]
# [Date "2014.09.07"]
# [Round "-"]
# [White "123lt"]
# [Black "kingbos"]
# [Result "1-0"]
# [BlackElo "1129"]
# [CurrentPosition "r5k1/3R4/p1p3pB/5p2/2P4P/6P1/PP6/6K1 w - -"]
# [ECO "D08"]
# [ECOUrl "https://www.chess.com/openings/Queens-Gambit-Declined-Albin-Countergambit-3.dxe5-d4"]
# [EndDate "2014.09.07"]
# [EndTime "03:15:08"]
# [Link "https://www.chess.com/live/game/907775078"]
# [StartTime "03:12:32"]
# [Termination "123lt won by resignation"]
# [TimeControl "120+1"]
# [Timezone "UTC"]
# [UTCDate "2014.09.07"]
# [UTCTime "03:12:32"]
# [WhiteElo "1343"]
#
# 1. d4 { [%clk 0:02:00] } 1... d5 { [%clk 0:02:01] } 2. c4 { [%clk 0:01:59.6] } 2... e5 { [%clk 0:02:00.8] } 3. dxe5 { [%clk 0:01:59.3] } 3... d4 { [%clk 0:02:00.6] } 4. g3 { [%clk 0:01:59.8] } 4... c5 { [%clk 0:01:57.3] } 5. Bg2 { [%clk 0:02:00.1] } 5... Qe7 { [%clk 0:01:48.5] } 6. Nf3 { [%clk 0:01:59.4] } 6... Bg4 { [%clk 0:01:46.7] } 7. O-O { [%clk 0:01:59.2] } 7... Bxf3 { [%clk 0:01:46.3] } 8. Bxf3 { [%clk 0:01:59] } 8... Nc6 { [%clk 0:01:46.4] } 9. Bxc6+ { [%clk 0:01:56] } 9... bxc6 { [%clk 0:01:46.4] } 10. f4 { [%clk 0:01:56.4] } 10... g6 { [%clk 0:01:39] } 11. e3 { [%clk 0:01:56] } 11... Bg7 { [%clk 0:01:38.8] } 12. exd4 { [%clk 0:01:55.5] } 12... cxd4 { [%clk 0:01:38.8] } 13. Qxd4 { [%clk 0:01:55.7] } 13... Nh6 { [%clk 0:01:27.4] } 14. Qd6 { [%clk 0:01:55.2] } 14... Qxd6 { [%clk 0:01:12.8] } 15. exd6 { [%clk 0:01:55] } 15... O-O { [%clk 0:01:11.7] } 16. Nc3 { [%clk 0:01:54.2] } 16... Rfd8 { [%clk 0:01:10.8] } 17. Ne4 { [%clk 0:01:53] } 17... f5 { [%clk 0:01:10.1] } 18. Ng5 { [%clk 0:01:52.8] } 18... Rxd6 { [%clk 0:01:07.1] } 19. Be3 { [%clk 0:01:52.8] } 19... Bf6 { [%clk 0:01:03.3] } 20. Rad1 { [%clk 0:01:51.3] } 20... Rxd1 { [%clk 0:01:02.5] } 21. Rxd1 { [%clk 0:01:50.9] } 21... Bxg5 { [%clk 0:01:02.6] } 22. fxg5 { [%clk 0:01:50.9] } 22... Nf7 { [%clk 0:01:02.6] } 23. Bf4 { [%clk 0:01:51] } 23... h6 { [%clk 0:00:54] } 24. gxh6 { [%clk 0:01:48.8] } 24... Kh7 { [%clk 0:00:54.2] } 25. h4 { [%clk 0:01:47.8] } 25... Nxh6 { [%clk 0:00:53.9] } 26. Rd7+ { [%clk 0:01:47] } 26... Kg8 { [%clk 0:00:49] } 27. Bxh6 { [%clk 0:01:46.9] } 27... a6 { [%clk 0:00:48.8] } 1-0

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests
from IPython.display import display

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        pgn = io.StringIO(gameUnparsed)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        print(gameUnparsed)
        # display(chess.svg.board(board))
        break
    break
# Out:
# [Event "Live Chess"]
# [Site "Chess.com"]
# [Date "2014.09.07"]
# [Round "-"]
# [White "123lt"]
# [Black "kingbos"]
# [Result "1-0"]
# [CurrentPosition "r5k1/3R4/p1p3pB/5p2/2P4P/6P1/PP6/6K1 w - -"]
# [Timezone "UTC"]
# [ECO "D08"]
# [ECOUrl "https://www.chess.com/openings/Queens-Gambit-Declined-Albin-Countergambit-3.dxe5-d4"]
# [UTCDate "2014.09.07"]
# [UTCTime "03:12:32"]
# [WhiteElo "1343"]
# [BlackElo "1129"]
# [TimeControl "120+1"]
# [Termination "123lt won by resignation"]
# [StartTime "03:12:32"]
# [EndDate "2014.09.07"]
# [EndTime "03:15:08"]
# [Link "https://www.chess.com/live/game/907775078"]
#
# 1. d4 {[%clk 0:02:00]} 1... d5 {[%clk 0:02:01]} 2. c4 {[%clk 0:01:59.6]} 2... e5 {[%clk 0:02:00.8]} 3. dxe5 {[%clk 0:01:59.3]} 3... d4 {[%clk 0:02:00.6]} 4. g3 {[%clk 0:01:59.8]} 4... c5 {[%clk 0:01:57.3]} 5. Bg2 {[%clk 0:02:00.1]} 5... Qe7 {[%clk 0:01:48.5]} 6. Nf3 {[%clk 0:01:59.4]} 6... Bg4 {[%clk 0:01:46.7]} 7. O-O {[%clk 0:01:59.2]} 7... Bxf3 {[%clk 0:01:46.3]} 8. Bxf3 {[%clk 0:01:59]} 8... Nc6 {[%clk 0:01:46.4]} 9. Bxc6+ {[%clk 0:01:56]} 9... bxc6 {[%clk 0:01:46.4]} 10. f4 {[%clk 0:01:56.4]} 10... g6 {[%clk 0:01:39]} 11. e3 {[%clk 0:01:56]} 11... Bg7 {[%clk 0:01:38.8]} 12. exd4 {[%clk 0:01:55.5]} 12... cxd4 {[%clk 0:01:38.8]} 13. Qxd4 {[%clk 0:01:55.7]} 13... Nh6 {[%clk 0:01:27.4]} 14. Qd6 {[%clk 0:01:55.2]} 14... Qxd6 {[%clk 0:01:12.8]} 15. exd6 {[%clk 0:01:55]} 15... O-O {[%clk 0:01:11.7]} 16. Nc3 {[%clk 0:01:54.2]} 16... Rfd8 {[%clk 0:01:10.8]} 17. Ne4 {[%clk 0:01:53]} 17... f5 {[%clk 0:01:10.1]} 18. Ng5 {[%clk 0:01:52.8]} 18... Rxd6 {[%clk 0:01:07.1]} 19. Be3 {[%clk 0:01:52.8]} 19... Bf6 {[%clk 0:01:03.3]} 20. Rad1 {[%clk 0:01:51.3]} 20... Rxd1 {[%clk 0:01:02.5]} 21. Rxd1 {[%clk 0:01:50.9]} 21... Bxg5 {[%clk 0:01:02.6]} 22. fxg5 {[%clk 0:01:50.9]} 22... Nf7 {[%clk 0:01:02.6]} 23. Bf4 {[%clk 0:01:51]} 23... h6 {[%clk 0:00:54]} 24. gxh6 {[%clk 0:01:48.8]} 24... Kh7 {[%clk 0:00:54.2]} 25. h4 {[%clk 0:01:47.8]} 25... Nxh6 {[%clk 0:00:53.9]} 26. Rd7+ {[%clk 0:01:47]} 26... Kg8 {[%clk 0:00:49]} 27. Bxh6 {[%clk 0:01:46.9]} 27... a6 {[%clk 0:00:48.8]} 1-0

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests
from IPython.display import display

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][1]['pgn']
        pgn = io.StringIO(gameUnparsed)
        parsed = chess.pgn.read_game(pgn)
        board = parsed.board()
        print(gameUnparsed)
        # display(chess.svg.board(board))
        break
    break
# Out:
# [Event "Live Chess"]
# [Site "Chess.com"]
# [Date "2014.09.07"]
# [Round "-"]
# [White "betablokator"]
# [Black "123lt"]
# [Result "0-1"]
# [CurrentPosition "4Q3/5pkp/4p1p1/8/4q3/7P/3r3K/6R1 w - -"]
# [Timezone "UTC"]
# [ECO "B21"]
# [ECOUrl "https://www.chess.com/openings/Sicilian-Defense-McDonnell-Attack-2...d5-3.e5"]
# [UTCDate "2014.09.07"]
# [UTCTime "03:15:33"]
# [WhiteElo "1266"]
# [BlackElo "1469"]
# [TimeControl "120+1"]
# [Termination "123lt won by resignation"]
# [StartTime "03:15:33"]
# [EndDate "2014.09.07"]
# [EndTime "03:18:59"]
# [Link "https://www.chess.com/live/game/907776561"]
#
# 1. e4 {[%clk 0:02:00]} 1... c5 {[%clk 0:02:00]} 2. f4 {[%clk 0:01:58.9]} 2... d5 {[%clk 0:01:59.6]} 3. e5 {[%clk 0:01:56.8]} 3... Nh6 {[%clk 0:01:58.3]} 4. Nf3 {[%clk 0:01:57.7]} 4... Nf5 {[%clk 0:01:56.4]} 5. Be2 {[%clk 0:01:58.6]} 5... Nc6 {[%clk 0:01:56.4]} 6. O-O {[%clk 0:01:59.5]} 6... e6 {[%clk 0:01:56.9]} 7. d3 {[%clk 0:01:58.9]} 7... Be7 {[%clk 0:01:56.5]} 8. Nbd2 {[%clk 0:01:59.1]} 8... Nfd4 {[%clk 0:01:56.4]} 9. c3 {[%clk 0:01:57]} 9... Nf5 {[%clk 0:01:56.2]} 10. Qc2 {[%clk 0:01:52.3]} 10... Ne3 {[%clk 0:01:56]} 11. Qb1 {[%clk 0:01:50.8]} 11... Nxf1 {[%clk 0:01:56.1]} 12. Kxf1 {[%clk 0:01:50.5]} 12... O-O {[%clk 0:01:55]} 13. d4 {[%clk 0:01:51.2]} 13... cxd4 {[%clk 0:01:48.6]} 14. Nxd4 {[%clk 0:01:52.1]} 14... Nxd4 {[%clk 0:01:46.5]} 15. cxd4 {[%clk 0:01:53]} 15... Qb6 {[%clk 0:01:46.8]} 16. Nf3 {[%clk 0:01:51.8]} 16... Bd7 {[%clk 0:01:46.7]} 17. Be3 {[%clk 0:01:51.1]} 17... Bb5 {[%clk 0:01:46.8]} 18. Bxb5 {[%clk 0:01:48]} 18... Qxb5+ {[%clk 0:01:47]} 19. Kg1 {[%clk 0:01:48.9]} 19... Rac8 {[%clk 0:01:47.3]} 20. Ng5 {[%clk 0:01:48]} 20... g6 {[%clk 0:01:47]} 21. Qd1 {[%clk 0:01:43.2]} 21... Bxg5 {[%clk 0:01:46.7]} 22. fxg5 {[%clk 0:01:42.2]} 22... Qxb2 {[%clk 0:01:46.9]} 23. Rb1 {[%clk 0:01:40.2]} 23... Qxa2 {[%clk 0:01:47.2]} 24. Rxb7 {[%clk 0:01:38.9]} 24... Rc2 {[%clk 0:01:47.1]} 25. Qf1 {[%clk 0:01:37.2]} 25... Qa3 {[%clk 0:01:46.3]} 26. Bf4 {[%clk 0:01:35.7]} 26... Qc3 {[%clk 0:01:45.1]} 27. Rxa7 {[%clk 0:01:33]} 27... Qxd4+ {[%clk 0:01:44.1]} 28. Kh1 {[%clk 0:01:26.9]} 28... Rf2 {[%clk 0:01:38.8]} 29. Qe1 {[%clk 0:01:16.9]} 29... Qxf4 {[%clk 0:01:37.8]} 30. Ra1 {[%clk 0:01:14.6]} 30... d4 {[%clk 0:01:36.5]} 31. Qd1 {[%clk 0:01:07.8]} 31... d3 {[%clk 0:01:36.5]} 32. Qxd3 {[%clk 0:01:06.7]} 32... Qxg5 {[%clk 0:01:36.6]} 33. Rg1 {[%clk 0:01:04]} 33... Rd8 {[%clk 0:01:36.5]} 34. Qa3 {[%clk 0:01:00.4]} 34... Rdd2 {[%clk 0:01:35.4]} 35. Qa8+ {[%clk 0:00:57.2]} 35... Kg7 {[%clk 0:01:35.8]} 36. h3 {[%clk 0:00:56]} 36... Qxe5 {[%clk 0:01:34.1]} 37. Qe8 {[%clk 0:00:49.9]} 37... Rxg2 {[%clk 0:01:30.8]} 38. Rxg2 {[%clk 0:00:48]} 38... Rd1+ {[%clk 0:01:31.1]} 39. Rg1 {[%clk 0:00:46.9]} 39... Qe4+ {[%clk 0:01:31.3]} 40. Kh2 {[%clk 0:00:47]} 40... Rd2+ {[%clk 0:01:31.6]} 0-1

# %%
import io
import chess
import chess.pgn
import chess.svg
import requests
from IPython.display import display

GMPlayersUrl = 'https://api.chess.com/pub/titled/GM'
r = requests.get(GMPlayersUrl)
if not r.ok:
   raise Exception('url does not return: ', url, ' with message ', r.text)
j = r.json()

for player in j['players']:
    monthlyArchivesUrl =  f'https://api.chess.com/pub/player/{player}/games/archives'
    r = requests.get(monthlyArchivesUrl)
    if not r.ok:
        raise Exception('url does not return: ', monthlyArchivesUrl, ' with message ', r.text)
    games = r.json()

    for game in games['archives']:
        r = requests.get(game)
        if not r.ok:
            raise Exception('url does not return: ', game, ' with message ', r.text)
        gameUnparsed = r.json()['games'][0]['pgn']
        pgn = io.StringIO(gameUnparsed)
        gameParsed = chess.pgn.read_game(pgn)

        print(gameParsed.headers['Date'] + '_' + gameParsed.headers['White'] + '_' + gameParsed.headers['Black'])
        # display(chess.svg.board(board))
        break
    break
# Out:
# 2014.09.07_123lt_kingbos
